# %%
# !pip install rasterio
# !pip install pytorch_lightning
# !pip install pytorch_tabular
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2025.10.5)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.0)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.2.5)
# Downloading rasterio-1.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 40.1 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Installing collected packages: cligj, click-plugins, affine, rasterio
# Successfully installed affine-2.4.0 click-plugins-1.1.1.2 cligj-0.7.2 rasterio-1.4.3
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.5.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (2.8.0+cu126)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.67.1)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2025.3.0)
# Collecting torchmetrics>0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (25.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.15.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.13.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.10.0->pytorch_lightning) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.4.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics>0.7.0->pytorch_lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.22.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.11)
# Downloading pytorch_lightning-2.5.5-py3-none-any.whl (832 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.4/832.4 kB 6.9 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 26.2 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch_lightning
# Successfully installed lightning-utilities-0.15.2 pytorch_lightning-2.5.5 torchmetrics-1.8.2
# Collecting pytorch_tabular
#   Downloading pytorch_tabular-1.1.1-py2.py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_tabular) (2.8.0+cu126)
# Collecting numpy<2.0,>1.20.0 (from pytorch_tabular)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from pytorch_tabular) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_tabular) (1.6.1)
# Collecting pytorch-lightning<2.5.0,>=2.0.0 (from pytorch_tabular)
#   Downloading pytorch_lightning-2.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: omegaconf>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_tabular) (2.3.0)
# Collecting torchmetrics<1.6.0,>=0.10.0 (from pytorch_tabular)
#   Downloading torchmetrics-1.5.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: tensorboard!=2.5.0,>2.2.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_tabular) (2.19.0)
# Collecting protobuf<5.29.0,>=3.20.0 (from pytorch_tabular)
#   Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting pytorch-tabnet==4.1 (from pytorch_tabular)
#   Downloading pytorch_tabnet-4.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: PyYAML<6.1.0,>=5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch_tabular) (6.0.3)
# Requirement already satisfied: matplotlib>3.1 in /usr/local/lib/python3.12/dist-packages (from pytorch_tabular) (3.10.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from pytorch_tabular) (7.7.1)
# Collecting einops<0.8.0,>=0.6.0 (from pytorch_tabular)
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: rich>=11.0.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_tabular) (13.9.4)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet==4.1->pytorch_tabular) (1.16.3)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet==4.1->pytorch_tabular) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.1->pytorch_tabular) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.1->pytorch_tabular) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.1->pytorch_tabular) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.1->pytorch_tabular) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.1->pytorch_tabular) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.1->pytorch_tabular) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.1->pytorch_tabular) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.1->pytorch_tabular) (2.9.0.post0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf>=2.3.0->pytorch_tabular) (4.9.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->pytorch_tabular) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->pytorch_tabular) (2025.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning<2.5.0,>=2.0.0->pytorch_tabular) (2025.3.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning<2.5.0,>=2.0.0->pytorch_tabular) (4.15.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning<2.5.0,>=2.0.0->pytorch_tabular) (0.15.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.0.0->pytorch_tabular) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.0.0->pytorch_tabular) (2.19.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.0->pytorch_tabular) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.0->pytorch_tabular) (3.6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular) (3.9)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->pytorch_tabular) (3.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->pytorch_tabular) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->pytorch_tabular) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->pytorch_tabular) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->pytorch_tabular) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->pytorch_tabular) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->pytorch_tabular) (3.0.15)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning<2.5.0,>=2.0.0->pytorch_tabular) (3.13.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->pytorch_tabular) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->pytorch_tabular) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->pytorch_tabular) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->pytorch_tabular) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->pytorch_tabular) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->pytorch_tabular) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->pytorch_tabular) (6.5.1)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->pytorch_tabular)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->pytorch_tabular) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->pytorch_tabular) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->pytorch_tabular) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->pytorch_tabular) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->pytorch_tabular) (4.9.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.0.0->pytorch_tabular) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->pytorch_tabular) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard!=2.5.0,>2.2.0->pytorch_tabular) (3.0.3)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (6.5.7)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.5.0,>=2.0.0->pytorch_tabular) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.5.0,>=2.0.0->pytorch_tabular) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.5.0,>=2.0.0->pytorch_tabular) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.5.0,>=2.0.0->pytorch_tabular) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.5.0,>=2.0.0->pytorch_tabular) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.5.0,>=2.0.0->pytorch_tabular) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.5.0,>=2.0.0->pytorch_tabular) (1.22.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->pytorch_tabular) (0.8.5)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pytorch_tabular) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pytorch_tabular) (5.9.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (0.23.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (1.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->pytorch_tabular) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->pytorch_tabular) (0.2.14)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pytorch_tabular) (4.5.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (4.25.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.5.0,>=2.0.0->pytorch_tabular) (3.11)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (1.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (0.28.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (2.8)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (2.23)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (4.11.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (1.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (1.3.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (24.11.1)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pytorch_tabular) (1.4.0)
# Downloading pytorch_tabular-1.1.1-py2.py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 4.3 MB/s eta 0:00:00
# Downloading pytorch_tabnet-4.1.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 2.7 MB/s eta 0:00:00
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 2.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 74.2 MB/s eta 0:00:00
# Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 19.7 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 40.8 MB/s eta 0:00:00
# Downloading torchmetrics-1.5.2-py3-none-any.whl (891 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 891.4/891.4 kB 44.3 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.6 MB/s eta 0:00:00
# Installing collected packages: protobuf, numpy, jedi, einops, torchmetrics, pytorch-tabnet, pytorch-lightning, pytorch_tabular
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.1
#     Uninstalling einops-0.8.1:
#       Successfully uninstalled einops-0.8.1
#   Attempting uninstall: torchmetrics
#     Found existing installation: torchmetrics 1.8.2
#     Uninstalling torchmetrics-1.8.2:
#       Successfully uninstalled torchmetrics-1.8.2
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.5.5
#     Uninstalling pytorch-lightning-2.5.5:
#       Successfully uninstalled pytorch-lightning-2.5.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 5.28.3 which is incompatible.
# Successfully installed einops-0.7.0 jedi-0.19.2 numpy-1.26.4 protobuf-5.28.3 pytorch-lightning-2.4.0 pytorch-tabnet-4.1.0 pytorch_tabular-1.1.1 torchmetrics-1.5.2

# %%
import os
import gc
import json
import glob
import joblib
import pickle
import rasterio
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm
from rasterio.transform import from_bounds
from sklearn.preprocessing import StandardScaler

# Install pyproj if needed for coordinate transformation
try:
    from pyproj import Transformer
except:
    print("Installing pyproj...")
    import subprocess
    subprocess.check_call(['pip', 'install', 'pyproj'])
    from pyproj import Transformer


import torch
import torch.nn as nn
import torch.nn.functional as F

import tensorflow as tf

from pytorch_tabular import TabularModel
from pytorch_tabular.models import FTTransformerConfig
from pytorch_tabular.config import DataConfig, OptimizerConfig, TrainerConfig

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Check GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# VARIABLES
MODEL_PATH = '/content/drive/MyDrive/Bathymetry/MODEL/PINN/base_model.keras'
TFRECORD_DIR = '/content/drive/MyDrive/Bathymetry/COASTALTFRecord'
OUTPUT_DIR = '/content/drive/MyDrive/Bathymetry/RESULT'
os.makedirs(OUTPUT_DIR, exist_ok=True)

PATCH_SIZE = 256
BATCH_SIZE = 2048  # Reduced for memory efficiency
TILE_CHUNK_SIZE = 512  # Process image in 512x512 chunks
TFRECORD_CRS = 'EPSG:32651'
EXPECTED_BANDS = 8

DEPTH_MIN = 0
DEPTH_MAX = 40.0

# %%
# =============================
# LOAD MODEL
# =============================

print("="*70)
print("LOADING BATHYMETRY MODEL")
print("="*70)

model = tf.keras.models.load_model(MODEL_PATH)
print(f"✓ Model loaded from: {MODEL_PATH}")
print(f"✓ Expected bands: {EXPECTED_BANDS}")

# Load scaler if exists
try:
    import pickle
    scaler_path = MODEL_PATH.replace('base_model.keras', 'scaler.pkl')
    with open(scaler_path, 'rb') as f:
        scaler = pickle.load(f)
    print(f"✓ Scaler loaded")
except:
    scaler = None
    print("⚠ No scaler found, will use raw values")

model.summary()
# Out:
# ======================================================================
# LOADING BATHYMETRY MODEL
# ======================================================================
# ✓ Model loaded from: /content/drive/MyDrive/Bathymetry/MODEL/PINN/base_model.keras
# ✓ Expected bands: 8
# ⚠ No scaler found, will use raw values
# Model: "ResNet_Bathymetry"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │        576 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64)        │        256 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      4,160 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      4,160 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 64)        │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 64)        │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │      8,320 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │     16,512 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │      8,320 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 128)       │          0 │ batch_normalizat… │
# │                     │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 128)       │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │     33,024 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_6[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 256)       │     65,792 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_7[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 256)       │     33,024 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 256)       │          0 │ batch_normalizat… │
# │                     │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 256)       │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 64)        │     16,448 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 64)        │          0 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 1)         │         65 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 194,241 (758.75 KB)
#  Trainable params: 192,321 (751.25 KB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# =============================
# TFRECORD PROCESSING (BATHYMETRY VERSION)
# =============================

def process_tfrecord_streaming_bathymetry(tfrecord_base_pattern, model, scaler, tile_bounds, expected_bands=8):
    """
    Process TFRecord for bathymetry estimation.
    Modified from classification version.
    """
    print(f"\nStreaming processing: {os.path.basename(tfrecord_base_pattern)}")

    # Find all files
    tfrecord_files = sorted(glob.glob(f"{tfrecord_base_pattern}-*.tfrecord.gz"))

    if not tfrecord_files:
        return None, None, None

    print(f"  Found {len(tfrecord_files)} file(s)")

    # Load mixer.json
    mixer_path = f"{tfrecord_base_pattern}-mixer.json"
    mixer = None
    if os.path.exists(mixer_path):
        with open(mixer_path, 'r') as f:
            mixer = json.load(f)
        print(f"  ✓ Loaded mixer.json")

    if not mixer or 'patchesPerRow' not in mixer:
        print("  ⚠️ No mixer.json found")
        return None, None, None

    # Get dimensions
    patches_per_row = mixer['patchesPerRow']
    total_patches = mixer['totalPatches']
    num_rows = int(np.ceil(total_patches / patches_per_row))

    print(f"  Grid: {num_rows} rows × {patches_per_row} cols ({total_patches} patches)")

    # Calculate output dimensions
    output_h = num_rows * PATCH_SIZE
    output_w = patches_per_row * PATCH_SIZE

    print(f"  Output size: {output_h} × {output_w} pixels")

    # Calculate bounds
    min_lon, min_lat, max_lon, max_lat = tile_bounds

    actual_pixel_size_lon = (max_lon - min_lon) / output_w
    actual_pixel_size_lat = (max_lat - min_lat) / output_h

    actual_max_lon = min_lon + (output_w * actual_pixel_size_lon)
    actual_max_lat = min_lat + (output_h * actual_pixel_size_lat)

    actual_bounds = [min_lon, min_lat, actual_max_lon, actual_max_lat]

    print(f"  Adjusted bounds: [{actual_bounds[0]:.6f}, {actual_bounds[1]:.6f}, {actual_bounds[2]:.6f}, {actual_bounds[3]:.6f}]")

    # Initialize output arrays (BATHYMETRY: depth instead of probability)
    depth_map = np.full((output_h, output_w), np.nan, dtype=np.float32)
    confidence_map = np.zeros((output_h, output_w), dtype=np.float32)

    # Band names
    band_names_ordered = ['B1', 'B2', 'B3', 'B4', 'B8', 'B8A', 'B11', 'B12']

    # Process patches
    patch_idx = 0
    total_valid_pixels = 0

    for file_idx, tfrecord_file in enumerate(tfrecord_files):
        print(f"  Processing file {file_idx+1}/{len(tfrecord_files)}")

        dataset = tf.data.TFRecordDataset(tfrecord_file, compression_type='GZIP')

        for raw_record in dataset:
            # Parse patch
            example = tf.train.Example()
            example.ParseFromString(raw_record.numpy())
            features = example.features.feature

            # Extract bands
            patch_data = {}
            for band_name in band_names_ordered:
                if band_name in features:
                    values = np.array(features[band_name].float_list.value)
                    patch_data[band_name] = values.reshape(PATCH_SIZE, PATCH_SIZE)

            if len(patch_data) != expected_bands:
                patch_idx += 1
                continue

            # Stack bands
            patch = np.stack([patch_data[bn] for bn in band_names_ordered], axis=-1)

            # Calculate position
            row_idx = patch_idx // patches_per_row
            col_idx = patch_idx % patches_per_row

            start_h = row_idx * PATCH_SIZE
            start_w = col_idx * PATCH_SIZE

            # Reshape to pixels
            pixels = patch.reshape(-1, expected_bands)
            n_pixels = len(pixels)

            # Find valid pixels
            valid_mask = ~np.any(np.isnan(pixels) | (pixels == 0), axis=1)
            valid_indices = np.where(valid_mask)[0]
            n_valid = len(valid_indices)

            if n_valid > 0:
                total_valid_pixels += n_valid

                # Normalize
                if scaler is not None:
                    import warnings
                    with warnings.catch_warnings():
                        warnings.filterwarnings('ignore')
                        valid_features = scaler.transform(pixels[valid_indices])
                else:
                    valid_features = pixels[valid_indices]

                # BATHYMETRY: Predict depths instead of probabilities
                patch_depths = np.full(n_pixels, np.nan, dtype=np.float32)

                # Process in batches
                for start_idx in range(0, n_valid, BATCH_SIZE):
                    end_idx = min(start_idx + BATCH_SIZE, n_valid)
                    batch_indices = valid_indices[start_idx:end_idx]

                    batch_features = valid_features[start_idx:end_idx]

                    # Predict depths
                    batch_depths = model.predict(batch_features, verbose=0).flatten()

                    # Clip to valid range
                    batch_depths = np.clip(batch_depths, DEPTH_MIN, DEPTH_MAX)

                    patch_depths[batch_indices] = batch_depths

                # Reshape and store
                patch_depth_map = patch_depths.reshape(PATCH_SIZE, PATCH_SIZE)
                depth_map[start_h:start_h+PATCH_SIZE, start_w:start_w+PATCH_SIZE] = patch_depth_map

                # Calculate confidence (simple: inverse normalized depth)
                patch_confidence = 1.0 - (patch_depth_map - DEPTH_MIN) / (DEPTH_MAX - DEPTH_MIN)
                patch_confidence = np.nan_to_num(patch_confidence, nan=0.0)
                confidence_map[start_h:start_h+PATCH_SIZE, start_w:start_w+PATCH_SIZE] = patch_confidence

            # Clean up
            del patch, pixels

            patch_idx += 1

            # Progress
            if patch_idx % 50 == 0:
                progress = (patch_idx / total_patches) * 100
                print(f"    Progress: {progress:.1f}% ({patch_idx}/{total_patches})")

            # Memory cleanup
            if patch_idx % 20 == 0:
                gc.collect()

    print(f"  ✓ Processed all {patch_idx} patches")

    # Statistics
    valid_depths = depth_map[~np.isnan(depth_map)]

    if len(valid_depths) > 0:
        print(f"\n  Depth Statistics:")
        print(f"    Valid pixels: {total_valid_pixels:,}")
        print(f"    Min depth:    {valid_depths.min():.2f} m")
        print(f"    Max depth:    {valid_depths.max():.2f} m")
        print(f"    Mean depth:   {valid_depths.mean():.2f} m")
        print(f"    Median depth: {np.median(valid_depths):.2f} m")

    return depth_map, confidence_map, actual_bounds

# %%
# =============================
# SAVE GEOTIFF (SAME AS BEFORE)
# =============================

def save_geotiff_aligned(array, output_path, bounds, crs):
    """Save array as GeoTIFF with proper georeferencing"""
    h, w = array.shape

    min_x, min_y, max_x, max_y = bounds

    pixel_width = (max_x - min_x) / w
    pixel_height = (max_y - min_y) / h

    transform = rasterio.transform.from_bounds(
        min_x, min_y, max_x, max_y, w, h
    )

    print(f"    Saving: {os.path.basename(output_path)}")
    print(f"      Size: {w} x {h}")
    print(f"      Bounds: {bounds}")

    with rasterio.open(
        output_path, 'w',
        driver='GTiff',
        height=h,
        width=w,
        count=1,
        dtype=array.dtype,
        crs=crs,
        transform=transform,
        compress='lzw',
        nodata=np.nan if array.dtype == np.float32 else -9999
    ) as dst:
        dst.write(array, 1)

    print(f"    ✓ Saved")


# =============================
# READ TILE MIXER (SAME AS BEFORE)
# =============================

def read_tile_mixer(tile_base_path):
    """Read mixer.json and extract georeferencing info"""
    mixer_path = f"{tile_base_path}-mixer.json"

    if not os.path.exists(mixer_path):
        raise FileNotFoundError(f"mixer.json not found: {mixer_path}")

    with open(mixer_path, 'r') as f:
        mixer = json.load(f)

    # Extract info
    crs = mixer['projection']['crs']
    patch_dims = mixer.get('patchDimensions', [256, 256])
    patches_per_row = mixer.get('patchesPerRow', 0)
    total_patches = mixer.get('totalPatches', 0)

    patches_per_col = total_patches // patches_per_row if patches_per_row > 0 else 0

    # Extract affine transform
    affine_matrix = mixer['projection']['affine']['doubleMatrix']

    scale_x = affine_matrix[0]
    translate_x = affine_matrix[2]
    scale_y = affine_matrix[4]
    translate_y = affine_matrix[5]

    # Calculate bounds
    patch_width_pixels = patch_dims[0]
    patch_height_pixels = patch_dims[1]

    total_width_pixels = patches_per_row * patch_width_pixels
    total_height_pixels = patches_per_col * patch_height_pixels

    min_x = translate_x
    max_y = translate_y
    max_x = min_x + (total_width_pixels * scale_x)
    min_y = max_y + (total_height_pixels * scale_y)

    bounds = [min_x, min_y, max_x, max_y]

    return {
        'crs': crs,
        'mixer': mixer,
        'patch_dims': patch_dims,
        'bounds': bounds,
        'grid_size': (patches_per_row, patches_per_col),
        'pixel_size': (scale_x, abs(scale_y))
    }

# %%
# =============================
# MAIN PROCESSING
# =============================

print("\n" + "="*70)
print("DISCOVERING TILES")
print("="*70)

# Find tiles
all_files = glob.glob(f"{TFRECORD_DIR}/*.tfrecord.gz")
tile_bases = set()

for file in all_files:
    basename = os.path.basename(file)
    base = basename.rsplit('-', 1)[0]
    tile_bases.add(os.path.join(TFRECORD_DIR, base))

tile_bases = sorted(tile_bases)
print(f"\nFound {len(tile_bases)} unique tiles")

# Read mixer.json for each
tile_info = []

for tile_base in tile_bases:
    basename = os.path.basename(tile_base)

    # Extract tile number
    import re
    match = re.search(r'tile[_-](\d+)', basename)
    tile_num = int(match.group(1)) if match else None

    try:
        mixer_data = read_tile_mixer(tile_base)

        tile_info.append({
            'base': tile_base,
            'number': tile_num,
            'bounds': mixer_data['bounds'],
            'crs': mixer_data['crs'],
            'mixer': mixer_data['mixer'],
            'grid_size': mixer_data['grid_size'],
            'pixel_size': mixer_data['pixel_size']
        })

        print(f"\n  Tile {tile_num}: {basename}")
        print(f"    CRS: {mixer_data['crs']}")
        print(f"    Grid: {mixer_data['grid_size'][0]} x {mixer_data['grid_size'][1]}")
        print(f"    Bounds: {mixer_data['bounds']}")

    except Exception as e:
        print(f"\n  ⚠ Error: {e}")
        continue

print(f"\n✓ Loaded {len(tile_info)} tiles with georeferencing")

if len(tile_info) == 0:
    raise ValueError("No valid tiles found!")
# Out:
# ======================================================================
# DISCOVERING TILES
# ======================================================================
#
# Found 81 unique tiles
#
#   Tile 28: S2_composite_2025_tile_028
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.46460486675275, 7.720301214779991, 117.99353290604232, 8.249229254069565]
#
#   Tile 29: S2_composite_2025_tile_029
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.46460486675275, 8.220303501920917, 117.99353290604232, 8.749231541210492]
#
#   Tile 30: S2_composite_2025_tile_030
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.46460486675275, 8.720305789061843, 117.99353290604232, 9.249233828351418]
#
#   Tile 31: S2_composite_2025_tile_031
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.46460486675275, 9.220308076202768, 117.99353290604232, 9.749236115492343]
#
#   Tile 32: S2_composite_2025_tile_032
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.46460486675275, 9.720310363343694, 117.99353290604232, 10.249238402633269]
#
#   Tile 33: S2_composite_2025_tile_033
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.46460486675275, 10.220312650484619, 117.99353290604232, 10.749240689774194]
#
#   Tile 34: S2_composite_2025_tile_034
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.46460486675275, 10.720404769153957, 117.99353290604232, 11.249332808443532]
#
#   Tile 35: S2_composite_2025_tile_035
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.46460486675275, 11.220407056294883, 117.99353290604232, 11.749335095584458]
#
#   Tile 36: S2_composite_2025_tile_036
#     CRS: EPSG:4326
#     Grid: 23 x 18
#     Bounds: [117.46460486675275, 11.699209102730588, 117.99353290604232, 12.113152785652863]
#
#   Tile 37: S2_composite_2025_tile_037
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.96460715389368, 7.720301214779991, 118.49353519318325, 8.249229254069565]
#
#   Tile 38: S2_composite_2025_tile_038
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.96460715389368, 8.220303501920917, 118.49353519318325, 8.749231541210492]
#
#   Tile 39: S2_composite_2025_tile_039
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.96460715389368, 8.720305789061843, 118.49353519318325, 9.249233828351418]
#
#   Tile 40: S2_composite_2025_tile_040
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.96460715389368, 9.220308076202768, 118.49353519318325, 9.749236115492343]
#
#   Tile 41: S2_composite_2025_tile_041
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.96460715389368, 9.720310363343694, 118.49353519318325, 10.249238402633269]
#
#   Tile 42: S2_composite_2025_tile_042
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.96460715389368, 10.220312650484619, 118.49353519318325, 10.749240689774194]
#
#   Tile 43: S2_composite_2025_tile_043
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.96460715389368, 10.720404769153957, 118.49353519318325, 11.249332808443532]
#
#   Tile 44: S2_composite_2025_tile_044
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [117.96460715389368, 11.220407056294883, 118.49353519318325, 11.749335095584458]
#
#   Tile 45: S2_composite_2025_tile_045
#     CRS: EPSG:4326
#     Grid: 23 x 18
#     Bounds: [117.96460715389368, 11.699209102730588, 118.49353519318325, 12.113152785652863]
#
#   Tile 46: S2_composite_2025_tile_046
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.4646094410346, 7.720301214779991, 118.99353748032416, 8.249229254069565]
#
#   Tile 47: S2_composite_2025_tile_047
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.4646094410346, 8.220303501920917, 118.99353748032416, 8.749231541210492]
#
#   Tile 48: S2_composite_2025_tile_048
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.4646094410346, 8.720305789061843, 118.99353748032416, 9.249233828351418]
#
#   Tile 49: S2_composite_2025_tile_049
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.4646094410346, 9.220308076202768, 118.99353748032416, 9.749236115492343]
#
#   Tile 50: S2_composite_2025_tile_050
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.4646094410346, 9.720310363343694, 118.99353748032416, 10.249238402633269]
#
#   Tile 51: S2_composite_2025_tile_051
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.4646094410346, 10.220312650484619, 118.99353748032416, 10.749240689774194]
#
#   Tile 52: S2_composite_2025_tile_052
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.4646094410346, 10.720404769153957, 118.99353748032416, 11.249332808443532]
#
#   Tile 53: S2_composite_2025_tile_053
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.4646094410346, 11.220407056294883, 118.99353748032416, 11.749335095584458]
#
#   Tile 54: S2_composite_2025_tile_054
#     CRS: EPSG:4326
#     Grid: 23 x 18
#     Bounds: [118.4646094410346, 11.699209102730588, 118.99353748032416, 12.113152785652863]
#
#   Tile 55: S2_composite_2025_tile_055
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.96461172817553, 7.720301214779991, 119.4935397674651, 8.249229254069565]
#
#   Tile 56: S2_composite_2025_tile_056
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.96461172817553, 8.220303501920917, 119.4935397674651, 8.749231541210492]
#
#   Tile 57: S2_composite_2025_tile_057
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.96461172817553, 8.720305789061843, 119.4935397674651, 9.249233828351418]
#
#   Tile 58: S2_composite_2025_tile_058
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.96461172817553, 9.220308076202768, 119.4935397674651, 9.749236115492343]
#
#   Tile 59: S2_composite_2025_tile_059
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.96461172817553, 9.720310363343694, 119.4935397674651, 10.249238402633269]
#
#   Tile 60: S2_composite_2025_tile_060
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.96461172817553, 10.220312650484619, 119.4935397674651, 10.749240689774194]
#
#   Tile 61: S2_composite_2025_tile_061
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.96461172817553, 10.720404769153957, 119.4935397674651, 11.249332808443532]
#
#   Tile 62: S2_composite_2025_tile_062
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [118.96461172817553, 11.220407056294883, 119.4935397674651, 11.749335095584458]
#
#   Tile 63: S2_composite_2025_tile_063
#     CRS: EPSG:4326
#     Grid: 23 x 18
#     Bounds: [118.96461172817553, 11.699209102730588, 119.4935397674651, 12.113152785652863]
#
#   Tile 64: S2_composite_2025_tile_064
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.46461401531646, 7.720301214779991, 119.99354205460602, 8.249229254069565]
#
#   Tile 65: S2_composite_2025_tile_065
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.46461401531646, 8.220303501920917, 119.99354205460602, 8.749231541210492]
#
#   Tile 66: S2_composite_2025_tile_066
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.46461401531646, 8.720305789061843, 119.99354205460602, 9.249233828351418]
#
#   Tile 67: S2_composite_2025_tile_067
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.46461401531646, 9.220308076202768, 119.99354205460602, 9.749236115492343]
#
#   Tile 68: S2_composite_2025_tile_068
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.46461401531646, 9.720310363343694, 119.99354205460602, 10.249238402633269]
#
#   Tile 69: S2_composite_2025_tile_069
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.46461401531646, 10.220312650484619, 119.99354205460602, 10.749240689774194]
#
#   Tile 70: S2_composite_2025_tile_070
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.46461401531646, 10.720404769153957, 119.99354205460602, 11.249332808443532]
#
#   Tile 71: S2_composite_2025_tile_071
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.46461401531646, 11.220407056294883, 119.99354205460602, 11.749335095584458]
#
#   Tile 72: S2_composite_2025_tile_072
#     CRS: EPSG:4326
#     Grid: 23 x 18
#     Bounds: [119.46461401531646, 11.699209102730588, 119.99354205460602, 12.113152785652863]
#
#   Tile 73: S2_composite_2025_tile_073
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.96461630245737, 7.720301214779991, 120.49354434174694, 8.249229254069565]
#
#   Tile 74: S2_composite_2025_tile_074
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.96461630245737, 8.220303501920917, 120.49354434174694, 8.749231541210492]
#
#   Tile 75: S2_composite_2025_tile_075
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.96461630245737, 8.720305789061843, 120.49354434174694, 9.249233828351418]
#
#   Tile 76: S2_composite_2025_tile_076
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.96461630245737, 9.220308076202768, 120.49354434174694, 9.749236115492343]
#
#   Tile 77: S2_composite_2025_tile_077
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.96461630245737, 9.720310363343694, 120.49354434174694, 10.249238402633269]
#
#   Tile 78: S2_composite_2025_tile_078
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.96461630245737, 10.220312650484619, 120.49354434174694, 10.749240689774194]
#
#   Tile 79: S2_composite_2025_tile_079
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.96461630245737, 10.720404769153957, 120.49354434174694, 11.249332808443532]
#
#   Tile 80: S2_composite_2025_tile_080
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [119.96461630245737, 11.220407056294883, 120.49354434174694, 11.749335095584458]
#
#   Tile 81: S2_composite_2025_tile_081
#     CRS: EPSG:4326
#     Grid: 23 x 18
#     Bounds: [119.96461630245737, 11.699209102730588, 120.49354434174694, 12.113152785652863]
#
#   Tile 82: S2_composite_2025_tile_082
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.4646185895983, 7.720301214779991, 120.99354662888787, 8.249229254069565]
#
#   Tile 83: S2_composite_2025_tile_083
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.4646185895983, 8.220303501920917, 120.99354662888787, 8.749231541210492]
#
#   Tile 84: S2_composite_2025_tile_084
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.4646185895983, 8.720305789061843, 120.99354662888787, 9.249233828351418]
#
#   Tile 85: S2_composite_2025_tile_085
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.4646185895983, 9.220308076202768, 120.99354662888787, 9.749236115492343]
#
#   Tile 86: S2_composite_2025_tile_086
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.4646185895983, 9.720310363343694, 120.99354662888787, 10.249238402633269]
#
#   Tile 87: S2_composite_2025_tile_087
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.4646185895983, 10.220312650484619, 120.99354662888787, 10.749240689774194]
#
#   Tile 88: S2_composite_2025_tile_088
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.4646185895983, 10.720404769153957, 120.99354662888787, 11.249332808443532]
#
#   Tile 89: S2_composite_2025_tile_089
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.4646185895983, 11.220407056294883, 120.99354662888787, 11.749335095584458]
#
#   Tile 90: S2_composite_2025_tile_090
#     CRS: EPSG:4326
#     Grid: 23 x 18
#     Bounds: [120.4646185895983, 11.699209102730588, 120.99354662888787, 12.113152785652863]
#
#   Tile 91: S2_composite_2025_tile_091
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.96462087673923, 7.720301214779991, 121.4935489160288, 8.249229254069565]
#
#   Tile 92: S2_composite_2025_tile_092
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.96462087673923, 8.220303501920917, 121.4935489160288, 8.749231541210492]
#
#   Tile 93: S2_composite_2025_tile_093
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.96462087673923, 8.720305789061843, 121.4935489160288, 9.249233828351418]
#
#   Tile 94: S2_composite_2025_tile_094
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.96462087673923, 9.220308076202768, 121.4935489160288, 9.749236115492343]
#
#   Tile 95: S2_composite_2025_tile_095
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.96462087673923, 9.720310363343694, 121.4935489160288, 10.249238402633269]
#
#   Tile 96: S2_composite_2025_tile_096
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.96462087673923, 10.220312650484619, 121.4935489160288, 10.749240689774194]
#
#   Tile 97: S2_composite_2025_tile_097
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.96462087673923, 10.720404769153957, 121.4935489160288, 11.249332808443532]
#
#   Tile 98: S2_composite_2025_tile_098
#     CRS: EPSG:4326
#     Grid: 23 x 23
#     Bounds: [120.96462087673923, 11.220407056294883, 121.4935489160288, 11.749335095584458]
#
#   Tile 99: S2_composite_2025_tile_099
#     CRS: EPSG:4326
#     Grid: 23 x 18
#     Bounds: [120.96462087673923, 11.699209102730588, 121.4935489160288, 12.113152785652863]
#
#   Tile 100: S2_composite_2025_tile_100
#     CRS: EPSG:4326
#     Grid: 3 x 23
#     Bounds: [121.46462316388015, 7.72021138325158, 121.53361377770052, 8.249139422541154]
#
#   Tile 101: S2_composite_2025_tile_101
#     CRS: EPSG:4326
#     Grid: 3 x 23
#     Bounds: [121.46462316388015, 8.220213670392505, 121.53361377770052, 8.74914170968208]
#
#   Tile 102: S2_composite_2025_tile_102
#     CRS: EPSG:4326
#     Grid: 3 x 23
#     Bounds: [121.46462316388015, 8.72021595753343, 121.53361377770052, 9.249143996823005]
#
#   Tile 103: S2_composite_2025_tile_103
#     CRS: EPSG:4326
#     Grid: 3 x 23
#     Bounds: [121.46462316388015, 9.220218244674356, 121.53361377770052, 9.749146283963931]
#
#   Tile 104: S2_composite_2025_tile_104
#     CRS: EPSG:4326
#     Grid: 3 x 23
#     Bounds: [121.46462316388015, 9.720220531815281, 121.53361377770052, 10.249148571104856]
#
#   Tile 105: S2_composite_2025_tile_105
#     CRS: EPSG:4326
#     Grid: 3 x 23
#     Bounds: [121.46462316388015, 10.220222818956207, 121.53361377770052, 10.749150858245782]
#
#   Tile 106: S2_composite_2025_tile_106
#     CRS: EPSG:4326
#     Grid: 3 x 23
#     Bounds: [121.46462316388015, 10.720225106097134, 121.53361377770052, 11.249153145386709]
#
#   Tile 107: S2_composite_2025_tile_107
#     CRS: EPSG:4326
#     Grid: 3 x 23
#     Bounds: [121.46462316388015, 11.220227393238059, 121.53361377770052, 11.749155432527633]
#
#   Tile 108: S2_composite_2025_tile_108
#     CRS: EPSG:4326
#     Grid: 3 x 18
#     Bounds: [121.46462316388015, 11.699119271202177, 121.53361377770052, 12.113062954124452]
#
# ✓ Loaded 81 tiles with georeferencing

# %%
# =============================
# PROCESS ALL TILES
# =============================

print("\n" + "="*70)
print("PROCESSING TILES FOR BATHYMETRY")
print("="*70)

results = []

for idx, tile_data in enumerate(tile_info):
    tile_base = tile_data['base']
    bounds = tile_data['bounds']
    tile_num = tile_data['number']
    crs = tile_data['crs']

    print(f"\n{'='*70}")
    print(f"TILE {tile_num} ({idx+1}/{len(tile_info)})")
    print(f"Base: {os.path.basename(tile_base)}")
    print(f"CRS: {crs}")
    print(f"Bounds: {bounds}")
    print('='*70)

    tile_name = f"tile_{tile_num}"

    try:
        # Process tile
        depth_map, confidence_map, actual_bounds = process_tfrecord_streaming_bathymetry(
            tile_base, model, scaler, bounds, EXPECTED_BANDS
        )

        if depth_map is None:
            print("  ⚠️ Failed to process")
            continue

        # Use actual bounds
        if actual_bounds:
            bounds = actual_bounds

        # Statistics
        valid_depths = depth_map[~np.isnan(depth_map)]
        n_valid = len(valid_depths)

        if n_valid > 0:
            mean_depth = valid_depths.mean()
            min_depth = valid_depths.min()
            max_depth = valid_depths.max()
            median_depth = np.median(valid_depths)

            print(f"\n  Tile Statistics:")
            print(f"    Valid pixels: {n_valid:,}")
            print(f"    Mean depth: {mean_depth:.2f} m")
            print(f"    Min depth: {min_depth:.2f} m")
            print(f"    Max depth: {max_depth:.2f} m")

            results.append({
                'tile': tile_num,
                'valid_pixels': n_valid,
                'mean_depth_m': mean_depth,
                'min_depth_m': min_depth,
                'max_depth_m': max_depth,
                'median_depth_m': median_depth
            })

        # Save outputs
        print(f"\n  Saving outputs...")
        save_geotiff_aligned(
            depth_map,
            f"{OUTPUT_DIR}/{tile_name}_depth.tif",
            bounds,
            crs
        )
        save_geotiff_aligned(
            confidence_map,
            f"{OUTPUT_DIR}/{tile_name}_confidence.tif",
            bounds,
            crs
        )

        # Create visualization
        print(f"  Creating visualization...")

        fig, axes = plt.subplots(1, 2, figsize=(14, 6))

        # Depth map
        im1 = axes[0].imshow(depth_map, cmap='viridis_r', vmin=DEPTH_MIN, vmax=DEPTH_MAX)
        axes[0].set_title(f'Bathymetry (Tile {tile_num})', fontsize=14)
        axes[0].axis('off')
        cbar1 = plt.colorbar(im1, ax=axes[0], fraction=0.046)
        cbar1.set_label('Depth (m)', rotation=270, labelpad=20)

        # Confidence map
        im2 = axes[1].imshow(confidence_map, cmap='RdYlGn', vmin=0, vmax=1)
        axes[1].set_title('Confidence', fontsize=14)
        axes[1].axis('off')
        cbar2 = plt.colorbar(im2, ax=axes[1], fraction=0.046)
        cbar2.set_label('Confidence', rotation=270, labelpad=20)

        if n_valid > 0:
            plt.suptitle(f'Mean Depth: {mean_depth:.2f}m | Range: {min_depth:.2f}-{max_depth:.2f}m',
                        fontsize=12)

        plt.tight_layout()
        plt.savefig(f"{OUTPUT_DIR}/{tile_name}_result.png", dpi=150, bbox_inches='tight')
        plt.close()

        print(f"  ✓ Saved all outputs")

        # Clean up
        del depth_map, confidence_map
        gc.collect()

    except Exception as e:
        print(f"  ✗ Error: {e}")
        import traceback
        traceback.print_exc()
        gc.collect()
# Out:
# ======================================================================
# PROCESSING TILES FOR BATHYMETRY
# ======================================================================
#
# ======================================================================
# TILE 28 (1/81)
# Base: S2_composite_2025_tile_028
# CRS: EPSG:4326
# Bounds: [117.46460486675275, 7.720301214779991, 117.99353290604232, 8.249229254069565]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_028
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.464605, 7.720301, 117.993533, 8.249229]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Saving outputs...
#     Saving: tile_28_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 7.720301214779991, 117.99353290604232, 8.249229254069565]
#     ✓ Saved
#     Saving: tile_28_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 7.720301214779991, 117.99353290604232, 8.249229254069565]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 29 (2/81)
# Base: S2_composite_2025_tile_029
# CRS: EPSG:4326
# Bounds: [117.46460486675275, 8.220303501920917, 117.99353290604232, 8.749231541210492]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_029
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.464605, 8.220304, 117.993533, 8.749232]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 1,415,728
#     Min depth:    0.19 m
#     Max depth:    30.84 m
#     Mean depth:   5.94 m
#     Median depth: 5.77 m
#
#   Tile Statistics:
#     Valid pixels: 1,415,728
#     Mean depth: 5.94 m
#     Min depth: 0.19 m
#     Max depth: 30.84 m
#
#   Saving outputs...
#     Saving: tile_29_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 8.220303501920917, 117.99353290604232, 8.749231541210492]
#     ✓ Saved
#     Saving: tile_29_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 8.220303501920917, 117.99353290604232, 8.749231541210492]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 30 (3/81)
# Base: S2_composite_2025_tile_030
# CRS: EPSG:4326
# Bounds: [117.46460486675275, 8.720305789061843, 117.99353290604232, 9.249233828351418]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_030
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.464605, 8.720306, 117.993533, 9.249234]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 1,486,707
#     Min depth:    0.00 m
#     Max depth:    32.91 m
#     Mean depth:   5.21 m
#     Median depth: 4.57 m
#
#   Tile Statistics:
#     Valid pixels: 1,486,707
#     Mean depth: 5.21 m
#     Min depth: 0.00 m
#     Max depth: 32.91 m
#
#   Saving outputs...
#     Saving: tile_30_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 8.720305789061843, 117.99353290604232, 9.249233828351418]
#     ✓ Saved
#     Saving: tile_30_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 8.720305789061843, 117.99353290604232, 9.249233828351418]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 31 (4/81)
# Base: S2_composite_2025_tile_031
# CRS: EPSG:4326
# Bounds: [117.46460486675275, 9.220308076202768, 117.99353290604232, 9.749236115492343]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_031
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.464605, 9.220308, 117.993533, 9.749236]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 673,745
#     Min depth:    0.00 m
#     Max depth:    32.91 m
#     Mean depth:   6.92 m
#     Median depth: 4.39 m
#
#   Tile Statistics:
#     Valid pixels: 673,745
#     Mean depth: 6.92 m
#     Min depth: 0.00 m
#     Max depth: 32.91 m
#
#   Saving outputs...
#     Saving: tile_31_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 9.220308076202768, 117.99353290604232, 9.749236115492343]
#     ✓ Saved
#     Saving: tile_31_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 9.220308076202768, 117.99353290604232, 9.749236115492343]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 32 (5/81)
# Base: S2_composite_2025_tile_032
# CRS: EPSG:4326
# Bounds: [117.46460486675275, 9.720310363343694, 117.99353290604232, 10.249238402633269]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_032
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.464605, 9.720310, 117.993533, 10.249238]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 15,837
#     Min depth:    0.61 m
#     Max depth:    20.31 m
#     Mean depth:   10.66 m
#     Median depth: 10.64 m
#
#   Tile Statistics:
#     Valid pixels: 15,837
#     Mean depth: 10.66 m
#     Min depth: 0.61 m
#     Max depth: 20.31 m
#
#   Saving outputs...
#     Saving: tile_32_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 9.720310363343694, 117.99353290604232, 10.249238402633269]
#     ✓ Saved
#     Saving: tile_32_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 9.720310363343694, 117.99353290604232, 10.249238402633269]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 33 (6/81)
# Base: S2_composite_2025_tile_033
# CRS: EPSG:4326
# Bounds: [117.46460486675275, 10.220312650484619, 117.99353290604232, 10.749240689774194]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_033
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.464605, 10.220313, 117.993533, 10.749241]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 23,164
#     Min depth:    0.32 m
#     Max depth:    18.06 m
#     Mean depth:   9.18 m
#     Median depth: 9.95 m
#
#   Tile Statistics:
#     Valid pixels: 23,164
#     Mean depth: 9.18 m
#     Min depth: 0.32 m
#     Max depth: 18.06 m
#
#   Saving outputs...
#     Saving: tile_33_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 10.220312650484619, 117.99353290604232, 10.749240689774194]
#     ✓ Saved
#     Saving: tile_33_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 10.220312650484619, 117.99353290604232, 10.749240689774194]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 34 (7/81)
# Base: S2_composite_2025_tile_034
# CRS: EPSG:4326
# Bounds: [117.46460486675275, 10.720404769153957, 117.99353290604232, 11.249332808443532]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_034
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.464605, 10.720405, 117.993533, 11.249333]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 91,848
#     Min depth:    0.00 m
#     Max depth:    25.25 m
#     Mean depth:   10.19 m
#     Median depth: 10.75 m
#
#   Tile Statistics:
#     Valid pixels: 91,848
#     Mean depth: 10.19 m
#     Min depth: 0.00 m
#     Max depth: 25.25 m
#
#   Saving outputs...
#     Saving: tile_34_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 10.720404769153957, 117.99353290604232, 11.249332808443532]
#     ✓ Saved
#     Saving: tile_34_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 10.720404769153957, 117.99353290604232, 11.249332808443532]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 35 (8/81)
# Base: S2_composite_2025_tile_035
# CRS: EPSG:4326
# Bounds: [117.46460486675275, 11.220407056294883, 117.99353290604232, 11.749335095584458]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_035
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.464605, 11.220407, 117.993533, 11.749335]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Saving outputs...
#     Saving: tile_35_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 11.220407056294883, 117.99353290604232, 11.749335095584458]
#     ✓ Saved
#     Saving: tile_35_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.46460486675275, 11.220407056294883, 117.99353290604232, 11.749335095584458]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 36 (9/81)
# Base: S2_composite_2025_tile_036
# CRS: EPSG:4326
# Bounds: [117.46460486675275, 11.699209102730588, 117.99353290604232, 12.113152785652863]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_036
#   Found 9 file(s)
#   ✓ Loaded mixer.json
#   Grid: 18 rows × 23 cols (414 patches)
#   Output size: 4608 × 5888 pixels
#   Adjusted bounds: [117.464605, 11.699209, 117.993533, 12.113153]
#   Processing file 1/9
#   Processing file 2/9
#     Progress: 12.1% (50/414)
#   Processing file 3/9
#     Progress: 24.2% (100/414)
#   Processing file 4/9
#     Progress: 36.2% (150/414)
#   Processing file 5/9
#     Progress: 48.3% (200/414)
#   Processing file 6/9
#     Progress: 60.4% (250/414)
#   Processing file 7/9
#     Progress: 72.5% (300/414)
#   Processing file 8/9
#     Progress: 84.5% (350/414)
#   Processing file 9/9
#     Progress: 96.6% (400/414)
#   ✓ Processed all 414 patches
#
#   Saving outputs...
#     Saving: tile_36_depth.tif
#       Size: 5888 x 4608
#       Bounds: [117.46460486675275, 11.699209102730588, 117.99353290604232, 12.113152785652863]
#     ✓ Saved
#     Saving: tile_36_confidence.tif
#       Size: 5888 x 4608
#       Bounds: [117.46460486675275, 11.699209102730588, 117.99353290604232, 12.113152785652863]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 37 (10/81)
# Base: S2_composite_2025_tile_037
# CRS: EPSG:4326
# Bounds: [117.96460715389368, 7.720301214779991, 118.49353519318325, 8.249229254069565]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_037
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.964607, 7.720301, 118.493535, 8.249229]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 385,595
#     Min depth:    0.00 m
#     Max depth:    25.07 m
#     Mean depth:   6.82 m
#     Median depth: 6.94 m
#
#   Tile Statistics:
#     Valid pixels: 385,595
#     Mean depth: 6.82 m
#     Min depth: 0.00 m
#     Max depth: 25.07 m
#
#   Saving outputs...
#     Saving: tile_37_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 7.720301214779991, 118.49353519318325, 8.249229254069565]
#     ✓ Saved
#     Saving: tile_37_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 7.720301214779991, 118.49353519318325, 8.249229254069565]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 38 (11/81)
# Base: S2_composite_2025_tile_038
# CRS: EPSG:4326
# Bounds: [117.96460715389368, 8.220303501920917, 118.49353519318325, 8.749231541210492]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_038
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.964607, 8.220304, 118.493535, 8.749232]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 14,782
#     Min depth:    0.62 m
#     Max depth:    20.49 m
#     Mean depth:   10.07 m
#     Median depth: 10.10 m
#
#   Tile Statistics:
#     Valid pixels: 14,782
#     Mean depth: 10.07 m
#     Min depth: 0.62 m
#     Max depth: 20.49 m
#
#   Saving outputs...
#     Saving: tile_38_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 8.220303501920917, 118.49353519318325, 8.749231541210492]
#     ✓ Saved
#     Saving: tile_38_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 8.220303501920917, 118.49353519318325, 8.749231541210492]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 39 (12/81)
# Base: S2_composite_2025_tile_039
# CRS: EPSG:4326
# Bounds: [117.96460715389368, 8.720305789061843, 118.49353519318325, 9.249233828351418]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_039
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.964607, 8.720306, 118.493535, 9.249234]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 1,160,684
#     Min depth:    0.00 m
#     Max depth:    22.03 m
#     Mean depth:   5.97 m
#     Median depth: 5.28 m
#
#   Tile Statistics:
#     Valid pixels: 1,160,684
#     Mean depth: 5.97 m
#     Min depth: 0.00 m
#     Max depth: 22.03 m
#
#   Saving outputs...
#     Saving: tile_39_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 8.720305789061843, 118.49353519318325, 9.249233828351418]
#     ✓ Saved
#     Saving: tile_39_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 8.720305789061843, 118.49353519318325, 9.249233828351418]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 40 (13/81)
# Base: S2_composite_2025_tile_040
# CRS: EPSG:4326
# Bounds: [117.96460715389368, 9.220308076202768, 118.49353519318325, 9.749236115492343]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_040
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.964607, 9.220308, 118.493535, 9.749236]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 1,286,283
#     Min depth:    0.00 m
#     Max depth:    26.18 m
#     Mean depth:   4.25 m
#     Median depth: 3.27 m
#
#   Tile Statistics:
#     Valid pixels: 1,286,283
#     Mean depth: 4.25 m
#     Min depth: 0.00 m
#     Max depth: 26.18 m
#
#   Saving outputs...
#     Saving: tile_40_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 9.220308076202768, 118.49353519318325, 9.749236115492343]
#     ✓ Saved
#     Saving: tile_40_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 9.220308076202768, 118.49353519318325, 9.749236115492343]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 41 (14/81)
# Base: S2_composite_2025_tile_041
# CRS: EPSG:4326
# Bounds: [117.96460715389368, 9.720310363343694, 118.49353519318325, 10.249238402633269]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_041
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.964607, 9.720310, 118.493535, 10.249238]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 272,606
#     Min depth:    0.11 m
#     Max depth:    23.63 m
#     Mean depth:   8.46 m
#     Median depth: 8.32 m
#
#   Tile Statistics:
#     Valid pixels: 272,606
#     Mean depth: 8.46 m
#     Min depth: 0.11 m
#     Max depth: 23.63 m
#
#   Saving outputs...
#     Saving: tile_41_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 9.720310363343694, 118.49353519318325, 10.249238402633269]
#     ✓ Saved
#     Saving: tile_41_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 9.720310363343694, 118.49353519318325, 10.249238402633269]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 42 (15/81)
# Base: S2_composite_2025_tile_042
# CRS: EPSG:4326
# Bounds: [117.96460715389368, 10.220312650484619, 118.49353519318325, 10.749240689774194]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_042
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.964607, 10.220313, 118.493535, 10.749241]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 64,650
#     Min depth:    0.05 m
#     Max depth:    20.43 m
#     Mean depth:   6.54 m
#     Median depth: 6.27 m
#
#   Tile Statistics:
#     Valid pixels: 64,650
#     Mean depth: 6.54 m
#     Min depth: 0.05 m
#     Max depth: 20.43 m
#
#   Saving outputs...
#     Saving: tile_42_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 10.220312650484619, 118.49353519318325, 10.749240689774194]
#     ✓ Saved
#     Saving: tile_42_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 10.220312650484619, 118.49353519318325, 10.749240689774194]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 43 (16/81)
# Base: S2_composite_2025_tile_043
# CRS: EPSG:4326
# Bounds: [117.96460715389368, 10.720404769153957, 118.49353519318325, 11.249332808443532]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_043
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.964607, 10.720405, 118.493535, 11.249333]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Saving outputs...
#     Saving: tile_43_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 10.720404769153957, 118.49353519318325, 11.249332808443532]
#     ✓ Saved
#     Saving: tile_43_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 10.720404769153957, 118.49353519318325, 11.249332808443532]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 44 (17/81)
# Base: S2_composite_2025_tile_044
# CRS: EPSG:4326
# Bounds: [117.96460715389368, 11.220407056294883, 118.49353519318325, 11.749335095584458]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_044
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [117.964607, 11.220407, 118.493535, 11.749335]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Saving outputs...
#     Saving: tile_44_depth.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 11.220407056294883, 118.49353519318325, 11.749335095584458]
#     ✓ Saved
#     Saving: tile_44_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [117.96460715389368, 11.220407056294883, 118.49353519318325, 11.749335095584458]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 45 (18/81)
# Base: S2_composite_2025_tile_045
# CRS: EPSG:4326
# Bounds: [117.96460715389368, 11.699209102730588, 118.49353519318325, 12.113152785652863]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_045
#   Found 9 file(s)
#   ✓ Loaded mixer.json
#   Grid: 18 rows × 23 cols (414 patches)
#   Output size: 4608 × 5888 pixels
#   Adjusted bounds: [117.964607, 11.699209, 118.493535, 12.113153]
#   Processing file 1/9
#   Processing file 2/9
#     Progress: 12.1% (50/414)
#   Processing file 3/9
#     Progress: 24.2% (100/414)
#   Processing file 4/9
#     Progress: 36.2% (150/414)
#   Processing file 5/9
#     Progress: 48.3% (200/414)
#   Processing file 6/9
#     Progress: 60.4% (250/414)
#   Processing file 7/9
#     Progress: 72.5% (300/414)
#   Processing file 8/9
#     Progress: 84.5% (350/414)
#   Processing file 9/9
#     Progress: 96.6% (400/414)
#   ✓ Processed all 414 patches
#
#   Saving outputs...
#     Saving: tile_45_depth.tif
#       Size: 5888 x 4608
#       Bounds: [117.96460715389368, 11.699209102730588, 118.49353519318325, 12.113152785652863]
#     ✓ Saved
#     Saving: tile_45_confidence.tif
#       Size: 5888 x 4608
#       Bounds: [117.96460715389368, 11.699209102730588, 118.49353519318325, 12.113152785652863]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 46 (19/81)
# Base: S2_composite_2025_tile_046
# CRS: EPSG:4326
# Bounds: [118.4646094410346, 7.720301214779991, 118.99353748032416, 8.249229254069565]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_046
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [118.464609, 7.720301, 118.993537, 8.249229]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 147,831
#     Min depth:    0.27 m
#     Max depth:    22.38 m
#     Mean depth:   4.78 m
#     Median depth: 3.07 m
#
#   Tile Statistics:
#     Valid pixels: 147,831
#     Mean depth: 4.78 m
#     Min depth: 0.27 m
#     Max depth: 22.38 m
#
#   Saving outputs...
#     Saving: tile_46_depth.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 7.720301214779991, 118.99353748032416, 8.249229254069565]
#     ✓ Saved
#     Saving: tile_46_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 7.720301214779991, 118.99353748032416, 8.249229254069565]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 47 (20/81)
# Base: S2_composite_2025_tile_047
# CRS: EPSG:4326
# Bounds: [118.4646094410346, 8.220303501920917, 118.99353748032416, 8.749231541210492]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_047
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [118.464609, 8.220304, 118.993537, 8.749232]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Saving outputs...
#     Saving: tile_47_depth.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 8.220303501920917, 118.99353748032416, 8.749231541210492]
#     ✓ Saved
#     Saving: tile_47_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 8.220303501920917, 118.99353748032416, 8.749231541210492]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 48 (21/81)
# Base: S2_composite_2025_tile_048
# CRS: EPSG:4326
# Bounds: [118.4646094410346, 8.720305789061843, 118.99353748032416, 9.249233828351418]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_048
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [118.464609, 8.720306, 118.993537, 9.249234]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 33,698
#     Min depth:    0.80 m
#     Max depth:    18.77 m
#     Mean depth:   9.96 m
#     Median depth: 10.40 m
#
#   Tile Statistics:
#     Valid pixels: 33,698
#     Mean depth: 9.96 m
#     Min depth: 0.80 m
#     Max depth: 18.77 m
#
#   Saving outputs...
#     Saving: tile_48_depth.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 8.720305789061843, 118.99353748032416, 9.249233828351418]
#     ✓ Saved
#     Saving: tile_48_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 8.720305789061843, 118.99353748032416, 9.249233828351418]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 49 (22/81)
# Base: S2_composite_2025_tile_049
# CRS: EPSG:4326
# Bounds: [118.4646094410346, 9.220308076202768, 118.99353748032416, 9.749236115492343]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_049
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [118.464609, 9.220308, 118.993537, 9.749236]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 979,360
#     Min depth:    0.14 m
#     Max depth:    27.90 m
#     Mean depth:   5.18 m
#     Median depth: 3.84 m
#
#   Tile Statistics:
#     Valid pixels: 979,360
#     Mean depth: 5.18 m
#     Min depth: 0.14 m
#     Max depth: 27.90 m
#
#   Saving outputs...
#     Saving: tile_49_depth.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 9.220308076202768, 118.99353748032416, 9.749236115492343]
#     ✓ Saved
#     Saving: tile_49_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 9.220308076202768, 118.99353748032416, 9.749236115492343]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 50 (23/81)
# Base: S2_composite_2025_tile_050
# CRS: EPSG:4326
# Bounds: [118.4646094410346, 9.720310363343694, 118.99353748032416, 10.249238402633269]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_050
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [118.464609, 9.720310, 118.993537, 10.249238]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 1,484,498
#     Min depth:    0.00 m
#     Max depth:    32.20 m
#     Mean depth:   3.92 m
#     Median depth: 3.14 m
#
#   Tile Statistics:
#     Valid pixels: 1,484,498
#     Mean depth: 3.92 m
#     Min depth: 0.00 m
#     Max depth: 32.20 m
#
#   Saving outputs...
#     Saving: tile_50_depth.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 9.720310363343694, 118.99353748032416, 10.249238402633269]
#     ✓ Saved
#     Saving: tile_50_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 9.720310363343694, 118.99353748032416, 10.249238402633269]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 51 (24/81)
# Base: S2_composite_2025_tile_051
# CRS: EPSG:4326
# Bounds: [118.4646094410346, 10.220312650484619, 118.99353748032416, 10.749240689774194]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_051
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [118.464609, 10.220313, 118.993537, 10.749241]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 182,129
#     Min depth:    0.00 m
#     Max depth:    21.74 m
#     Mean depth:   5.11 m
#     Median depth: 4.61 m
#
#   Tile Statistics:
#     Valid pixels: 182,129
#     Mean depth: 5.11 m
#     Min depth: 0.00 m
#     Max depth: 21.74 m
#
#   Saving outputs...
#     Saving: tile_51_depth.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 10.220312650484619, 118.99353748032416, 10.749240689774194]
#     ✓ Saved
#     Saving: tile_51_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 10.220312650484619, 118.99353748032416, 10.749240689774194]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 52 (25/81)
# Base: S2_composite_2025_tile_052
# CRS: EPSG:4326
# Bounds: [118.4646094410346, 10.720404769153957, 118.99353748032416, 11.249332808443532]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_052
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [118.464609, 10.720405, 118.993537, 11.249333]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 192,733
#     Min depth:    0.00 m
#     Max depth:    22.17 m
#     Mean depth:   5.32 m
#     Median depth: 4.97 m
#
#   Tile Statistics:
#     Valid pixels: 192,733
#     Mean depth: 5.32 m
#     Min depth: 0.00 m
#     Max depth: 22.17 m
#
#   Saving outputs...
#     Saving: tile_52_depth.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 10.720404769153957, 118.99353748032416, 11.249332808443532]
#     ✓ Saved
#     Saving: tile_52_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 10.720404769153957, 118.99353748032416, 11.249332808443532]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 53 (26/81)
# Base: S2_composite_2025_tile_053
# CRS: EPSG:4326
# Bounds: [118.4646094410346, 11.220407056294883, 118.99353748032416, 11.749335095584458]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_053
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [118.464609, 11.220407, 118.993537, 11.749335]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Depth Statistics:
#     Valid pixels: 21,673
#     Min depth:    0.02 m
#     Max depth:    22.95 m
#     Mean depth:   8.01 m
#     Median depth: 6.67 m
#
#   Tile Statistics:
#     Valid pixels: 21,673
#     Mean depth: 8.01 m
#     Min depth: 0.02 m
#     Max depth: 22.95 m
#
#   Saving outputs...
#     Saving: tile_53_depth.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 11.220407056294883, 118.99353748032416, 11.749335095584458]
#     ✓ Saved
#     Saving: tile_53_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [118.4646094410346, 11.220407056294883, 118.99353748032416, 11.749335095584458]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 54 (27/81)
# Base: S2_composite_2025_tile_054
# CRS: EPSG:4326
# Bounds: [118.4646094410346, 11.699209102730588, 118.99353748032416, 12.113152785652863]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_054
#   Found 9 file(s)
#   ✓ Loaded mixer.json
#   Grid: 18 rows × 23 cols (414 patches)
#   Output size: 4608 × 5888 pixels
#   Adjusted bounds: [118.464609, 11.699209, 118.993537, 12.113153]
#   Processing file 1/9
#   Processing file 2/9
#     Progress: 12.1% (50/414)
#   Processing file 3/9
#     Progress: 24.2% (100/414)
#   Processing file 4/9
#     Progress: 36.2% (150/414)
#   Processing file 5/9
#     Progress: 48.3% (200/414)
#   Processing file 6/9
#     Progress: 60.4% (250/414)
#   Processing file 7/9
#     Progress: 72.5% (300/414)
#   Processing file 8/9
#     Progress: 84.5% (350/414)
#   Processing file 9/9
#     Progress: 96.6% (400/414)
#   ✓ Processed all 414 patches
#
#   Saving outputs...
#     Saving: tile_54_depth.tif
#       Size: 5888 x 4608
#       Bounds: [118.4646094410346, 11.699209102730588, 118.99353748032416, 12.113152785652863]
#     ✓ Saved
#     Saving: tile_54_confidence.tif
#       Size: 5888 x 4608
#       Bounds: [118.4646094410346, 11.699209102730588, 118.99353748032416, 12.113152785652863]
#     ✓ Saved
#   Creating visualization...
#   ✓ Saved all outputs
#
# ======================================================================
# TILE 55 (28/81)
# Base: S2_composite_2025_tile_055
# CRS: EPSG:4326
# Bounds: [118.96461172817553, 7.720301214779991, 119.4935397674651, 8.249229254069565]
# ======================================================================
#
# Streaming processing: S2_composite_2025_tile_055
#   Found 11 file(s)
#   ✓ Loaded mixer.json
#   Grid: 23 rows × 23 cols (529 patches)
#   Output size: 5888 × 5888 pixels
#   Adjusted bounds: [118.964612, 7.720301, 119.493540, 8.249229]
#   Processing file 1/11
#   Processing file 2/11
#     Progress: 9.5% (50/529)
#   Processing file 3/11
#     Progress: 18.9% (100/529)
#   Processing file 4/11
#     Progress: 28.4% (150/529)
#   Processing file 5/11
#     Progress: 37.8% (200/529)
#   Processing file 6/11
#     Progress: 47.3% (250/529)
#   Processing file 7/11
#     Progress: 56.7% (300/529)
#   Processing file 8/11
#     Progress: 66.2% (350/529)
#   Processing file 9/11
#     Progress: 75.6% (400/529)
#   Processing file 10/11
#     Progress: 85.1% (450/529)
#   Processing file 11/11
#     Progress: 94.5% (500/529)
#   ✓ Processed all 529 patches
#
#   Saving outputs...
#     Saving: tile_55_depth.tif
#       Size: 5888 x 5888
#       Bounds: [118.96461172817553, 7.720301214779991, 119.4935397674651, 8.249229254069565]
#     ✓ Saved
#     Saving: tile_55_confidence.tif
#       Size: 5888 x 5888
#       Bounds: [118.96461172817553, 7.720301214779991, 119.4935397674651, 8.249229254069565]
#     ✓ Saved
#   Creating visualization...
